# %% [markdown]
# # 🛠️ Utility Functions & Helpers
# This notebook contains reusable helper functions for logging, metrics calculation, file organization, and visualization used across other notebooks.
#
# ---

# %% [markdown]
# ### ✅ Print Both Files and Folders

# %%
import os

def print_directory_structure(base_path, indent=""):
    for entry in os.listdir(base_path):
        full_path = os.path.join(base_path, entry)
        if os.path.isdir(full_path):
            print(f"{indent}📁 {entry}/")
            print_directory_structure(full_path, indent + "    ")
        else:
            print(f"{indent}📄 {entry}")

# Example usage
print_directory_structure("../../src")  # Replace './' with your target path
# Out:
# 📄 .DS_Store
# 📁 core/
#     📄 server.py
#     📄 config.py
#     📄 client.py
#     📁 __pycache__/
#         📄 server.cpython-311.pyc
#         📄 config.cpython-311.pyc
#         📄 logger.cpython-311.pyc
#         📄 client.cpython-311.pyc
#         📄 model.cpython-310.pyc
#         📄 model.cpython-311.pyc
#         📄 fl_model.cpython-311.pyc
#         📄 utils.cpython-311.pyc
#         📄 tap_detection.cpython-311.pyc
#     📄 logger.py
#     📄 model.py
#     📄 utils.py
#     📄 tap_detection.py
#     📄 evaluate_all_models.py
# 📁 experiment-notebooks/
#     📄 01_tap_extractor_raw_audio.ipynb
#     📄 07_tain_test_data_validation.ipynb
#     📄 04_distribute_iid_clients.ipynb
#     📄 05_validate_distribution.ipynb
#     📄 11_test_global_model.ipynb
#     📄 05_distribute_non_iid_clients.ipynb
#     📄 10_utility.ipynb
#     📄 06_preprocess_audio_to_npy.ipynb
#     📄 00_extract_audio_from_video.ipynb
#     📄 09_evaluate_model.ipynb
#     📄 03_boxplot_class_ratios.ipynb
#     📄 02_audio_augmentation.ipynb
#     📄 08_standalone_model_train.ipynb

# %% [markdown]
# ### ✅ Print Only Folders

# %%
import os

def print_folders_only(base_path, indent=""):
    for entry in os.listdir(base_path):
        full_path = os.path.join(base_path, entry)
        if os.path.isdir(full_path):
            print(f"{indent}📁 {entry}/")
            print_folders_only(full_path, indent + "    ")

# Example usage
print_folders_only("../../logs")
# Out:
# 📁 standalone/
#     📁 IID/
#     📁 non-IID/
# 📁 global/
#     📁 v1.0.0/
#         📁 IID/
#         📁 non-IID/

# %% [markdown]
# ### ✅ Print Only Files

# %%
import os

def print_files_only(base_path, indent=""):
    for entry in os.listdir(base_path):
        full_path = os.path.join(base_path, entry)
        if os.path.isfile(full_path):
            print(f"{indent}📄 {entry}")
        elif os.path.isdir(full_path):
            print_files_only(full_path, indent + "    ")

# Example usage
print_files_only("../../logs")
# Out:
#     📄 .DS_Store
#         📄 model_train_log_2025-07-29_16-08-47.log
#         📄 evaluate_model_log_2025-07-29_18-35-36.log
#         📄 model_train_log_2025-07-31_01-11-18.log
#         📄 model_train_log_2025-07-29_16-22-16.log
#         📄 model_train_log_2025-07-30_23-51-03.log
#         📄 evaluate_model_log_2025-07-29_18-46-42.log
#             📄 model_train_server_log.log
#             📄 model_train_client_log.log
#             📄 evaluate_model_log.log
#         📄 all_model_compare_log.log
#             📄 model_train_server_log.log
#             📄 model_train_client_log.log
#             📄 test_real_audio_2025-07-30_13-41-17.log
#             📄 evaluate_model_log.log
